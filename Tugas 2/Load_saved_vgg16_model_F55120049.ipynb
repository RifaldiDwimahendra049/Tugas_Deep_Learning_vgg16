# %%
from google.colab import drive
import keras,os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import os

# %%
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/DeepLearning/
# Out:
# /content/gdrive/MyDrive/DeepLearning

# %%
# %ls
# Out:
# hilux.jpeg  mobil_x_motor.zip  test/   Vega.jpg
# Kijang.jpg  Pajero.jpeg        train/  vgg16.h5

# %%
from tensorflow.keras.models import load_model
vgg16_model = load_model('vgg16.h5')

# %%
img = Image.open("Kijang.jpg")

img = img.resize((224, 224))
img = np.asarray(img)
plt.imshow(img)
img = np.expand_dims(img, axis=0)


output = vgg16_model.predict(img)

if output[0][0] > output[0][1]:
    print("Motor")
    print("akurasi :",round(output[0][0]*100, 2),"%")
else:
    print('Mobil')
    print("akurasi :",round(output[0][1]*100,2),"%")
# Out:
# 1/1 [==============================] - 1s 533ms/step
# Mobil
# akurasi : 50.06 %

# %%
img = Image.open("beat.jpg")

img = img.resize((224, 224))
img = np.asarray(img)
plt.imshow(img)
img = np.expand_dims(img, axis=0)


output = vgg16_model.predict(img)

if output[0][0] > output[0][1]:
    print("Motor")
    print("akurasi :",round(output[0][0]*100, 2),"%")
else:
    print('Mobil')
    print("akurasi :",round(output[0][1]*100,2),"%")
# Out:
# 1/1 [==============================] - 1s 538ms/step
# Motor
# akurasi : 51.25 %
